# %% [markdown]
# <a href="https://colab.research.google.com/github/vavana619/quant_machine/blob/main/%5B6%EC%9E%A5%5D_%EC%9A%B0%EB%9F%89%EC%A3%BC%EB%A5%BC_%EC%B0%BE%EB%8A%94_%EA%B8%B0%EC%88%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 투자 효율이 좋은 기업, ROA(자산대비이익)와 ROE(자본대비이익)
#
# ## [ROA(자산대비이익)]
# : 회사가 가진 **총자산을 이용해 얼마나 벌어왔는지 그 수익률을 파악**할 수 있게 하는 지표 (ROA가 0.1이라면 10% 수익을 만들었다는 뜻)
#
# ![ROA.png](data:image/png;base64,...)

# %% [markdown]
# ## [ROE(자본대비이익)]
# : ROA와 같은 개념이나 자산 대신 *자본(순자산)*으로 산출
#
# ![image.png](data:image/png;base64,...)
